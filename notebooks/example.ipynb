# %%
import torch
from en_indic_transformer import Transformer
# Out:
# /Users/sameergururajmathad/en-indic-transformer/venv/lib/python3.12/site-packages/torch/_subclasses/functional_tensor.py:279: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))

# %%
transfomer = Transformer(50257, 4096, 768, 5, 5, 12, 0.1, False)

# %% [markdown]
# dry run

# %%
x = torch.randint(0, 4096, size=(1, 4096))

# %%
y = transfomer(x, x)

# %%
y.shape
# Out:
# torch.Size([1, 4096, 50257])
