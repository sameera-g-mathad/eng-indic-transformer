# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Set the path to the data directory
#
# ```python
# data_dir = "/path/to/your/data/directory"
# ```

# %%
path = Path()

# %% [markdown]
# This will be used as a base path for downloading and storing datasets.

# %%
save_dir = path.absolute().parent / 'data'

# %% [markdown]
# This will create the directory if it does not exist already.

# %%
Path.mkdir(save_dir, exist_ok=True, parents=True)

# %% [markdown]
# ### Get the english to hindi data from huggingface.
# The dataset is in parquet format. This data contains English to Hindi translations.
#
# * Need to install `pandas` for reading files.
# * Additionally, need to install `pyarrow`, `huggingface_hub`, `fastparquet` for downloading datasets from huggingface.
# * The dataset is downloaded from [huggingace](https://huggingface.co/datasets/damerajee/english-to-hindi-l).
#
# ```python

# %%
# en_hi_df = pd.read_parquet("hf://datasets/Aarif1430/english-to-hindi/data/train-00000-of-00001-71c2cec7402cd444.parquet")
en_hi_df = pd.read_parquet("hf://datasets/damerajee/english-to-hindi-l/data/train-00000-of-00001.parquet") # contains 1.79M records

# %%
en_hi_df
# Out:
#                                           english_sentence  \
# 0        When it is said to him: 'Fear Allah' egotism t...
# 1                             This profile exists already.
# 2                               Halo with Ornamental Borde
# 3        and the jinn We had created before from flamin...
# 4        Ladies and Gentlemen, the Government of India ...
# ...                                                    ...
# 1786783           Gaja cyclone in Tamil Nadu on 16.11.2018
# 1786784              PRESIDENT OF INDIA APPOINTS GOVERNORS
# 1786785              is a phenomenon that 's been promised
# 1786786                                Move waste to stock
# 1786787  If 19th century was the century of empires and...
#
#                                             hindi_sentence
# 0        और जब उससे कहा जाता है, "अल्लाह से डर", तो अहं...
# 1                             यह प्रोफ़ाइल पहले से ही है.
# 2        विवरण: एक पारंपरिक कमल के फूल के साथ पत्थर की ...
# 3        और हम ही ने जिन्नात को आदमी से (भी) पहले वे धु...
# 4        शहरीकरण की तेज गति के साथ अवसंरचना और सेवाओं क...
# ...                                                    ...
# 1786783              तमिलनाडू में गजा चक्रवात - 16.11.2018
# 1786784    भारत के राष्ट्रपति ने राज्यपालों की नियुक्ति की
# 1786785            एक ऐसी घटना है, जिसकी संभावना दशकों तक
# 1786786                        बेकार को भण्डार में ले जाएँ
# 1786787  जहां 19वीं सदी साम्राज्यों की तथा20वीं सदी राष...
#
# [1786788 rows x 2 columns]

# %%
en_hi_df.to_csv(save_dir / 'en_hindi.csv', index=False) # not saving indeces.

# %% [markdown]
# ### Get the english to kannada data from huggingface.
# The dataset is in parquet format. This data contains English to Kannada translations.
# * The dataset is downloaded from [huggingace](https://huggingface.co/datasets/damerajee/en-kannada).

# %%
# en_kn_df = pd.read_parquet("hf://datasets/Hemanth-thunder/english-to-kannada-mt/data/train-00000-of-00001.parquet")
en_kn_df = pd.read_csv("hf://datasets/damerajee/en-kannada/en-kannada-2.csv") # around 4M records

# %% [markdown]
# There are 4_093_524 rows in the downloaded dataset with two columns.

# %%
en_kn_df
# Out:
#                                          english_sentences  \
# 0                                         Hes a scientist.
# 1        'But we speak the truth aur ye sach hai ke Guj...
# 2                           8 lakh crore have been looted.
# 3                          I read a lot into this as well.
# 4        She was found dead with the phone's battery ex...
# ...                                                    ...
# 4093519                                    It was visible.
# 4093520     The Congress has yet not named its candidates.
# 4093521                      It is the centre of business.
# 4093522            How long does it take to start working?
# 4093523  This might prove to be a turning point for the...
#
#                                          kannada_sentences
# 0                                  ಇವರು ಸಂಶೋಧಕ ಸ್ವಭಾವದವರು.
# 1        "ಆದರೆ ಸತ್ಯ ಹೊರ ಬಂದೇ ಬರುತ್ತದೆ ಎಂದು ಹೇಳಿದ ರಾಹುಲ್...
# 2                                 ಕಳ್ಳತನವಾಗಿದ್ದ 8 ಲಕ್ಷ ರೂ.
# 3                        ಇದರ ಬಗ್ಗೆ ನಾನೂ ಸಾಕಷ್ಟು ಓದಿದ್ದೇನೆ.
# 4        ಆಕೆಯ ತಲೆಯ ಹತ್ತಿರ ಇರಿಸಿಕೊಂಡಿದ್ದ ಫೋನ್‌ನ ಬ್ಯಾಟರಿ ...
# ...                                                    ...
# 4093519                                      ಅದೂಯಶ ಕಂಡಿತು.
# 4093520  ಕಾಂಗ್ರೆಸ್ ಪಕ್ಷ ಇನ್ನೂ ಅಭ್ಯರ್ಥಿಗಳನ್ನು ಘೋಷಣೆ ಮಾಡಿ...
# 4093521                         ಇದು ವ್ಯಾಪಾರ ಕೇಂದ್ರವೂ ಹೌದು.
# 4093522            ಕೆಲಸ ಮಾಡಲು ಎಷ್ಟು ಸಮಯ ತೆಗೆದುಕೊಳ್ಳುತ್ತದೆ?
# 4093523    ಹಾಗೆ ನೋಡಿದರೆ ಬಿಜೆಪಿ ಪಾಲಿಗೆ ಇದು ಸಂಕ್ರಮಣ ಘಟ್ಟವೇ .
#
# [4093524 rows x 2 columns]

# %% [markdown]
# I am matching the naming convention for columns

# %%
# columns = {
#     'en': 'english_sentence',
#     'kn': 'kannada_sentence'
# }

columns = {
    'english_sentences': 'english_sentence',
    'kannada_sentences': 'kannada_sentence'
}

# %%
en_kn_df = en_kn_df.rename(columns=columns)

# %%
en_kn_df
# Out:
#                                           english_sentence  \
# 0                                         Hes a scientist.
# 1        'But we speak the truth aur ye sach hai ke Guj...
# 2                           8 lakh crore have been looted.
# 3                          I read a lot into this as well.
# 4        She was found dead with the phone's battery ex...
# ...                                                    ...
# 2046757                                       3000 to Rs .
# 2046758                        What are the other options?
# 2046759  But the tournament was postponed due to corona...
# 2046760  The effect of such human reasoning may be that...
# 2046761                             Trees and wild grasses
#
#                                           kannada_sentence
# 0                                  ಇವರು ಸಂಶೋಧಕ ಸ್ವಭಾವದವರು.
# 1        "ಆದರೆ ಸತ್ಯ ಹೊರ ಬಂದೇ ಬರುತ್ತದೆ ಎಂದು ಹೇಳಿದ ರಾಹುಲ್...
# 2                                 ಕಳ್ಳತನವಾಗಿದ್ದ 8 ಲಕ್ಷ ರೂ.
# 3                        ಇದರ ಬಗ್ಗೆ ನಾನೂ ಸಾಕಷ್ಟು ಓದಿದ್ದೇನೆ.
# 4        ಆಕೆಯ ತಲೆಯ ಹತ್ತಿರ ಇರಿಸಿಕೊಂಡಿದ್ದ ಫೋನ್‌ನ ಬ್ಯಾಟರಿ ...
# ...                                                    ...
# 2046757                                      ನಿಂದ 3000 ರೂ.
# 2046758                             ಬೇರೆ ಸಾಧ್ಯತೆಗಳು ಏನಿವೆ?
# 2046759  ಆದರೆ ಕೊರೊನೊ ಸೋಂಕಿನಿಂದಾಗಿ ಟೂರ್ನಿಯನ್ನು ಮುಂದೂಡಲಾಗ...
# 2046760  ಅವು ನಮ್ಮಲ್ಲಿ ಪ್ರತಿಯೊಬ್ಬನಿಗೆ ಪ್ರಾಮುಖ್ಯವಾಗಿವೆ ಮತ...
# 2046761                      ಸ್ಟ್ಯಾಂಪ್ ಮರಗಳು ಮತ್ತು ಪೊದೆಗಳು
#
# [2046762 rows x 2 columns]

# %% [markdown]
# Will be using `50%` rows of data to match the size of english to hindi dataset for now.

# %%
size = 0.5
en_kn_length = int(len(en_kn_df) * size)

# %%
en_kn_df = en_kn_df.iloc[:en_kn_length, :]

# %%
en_kn_df
# Out:
#                                           english_sentence  \
# 0                                         Hes a scientist.
# 1        'But we speak the truth aur ye sach hai ke Guj...
# 2                           8 lakh crore have been looted.
# 3                          I read a lot into this as well.
# 4        She was found dead with the phone's battery ex...
# ...                                                    ...
# 1023376  The Devala police registered a case in this co...
# 1023377         There is no proper treatment for patients.
# 1023378               Enter bank account number, IFSC code
# 1023379          The news spread like wildfire all across.
# 1023380  If possible, return what is borrowed to the le...
#
#                                           kannada_sentence
# 0                                  ಇವರು ಸಂಶೋಧಕ ಸ್ವಭಾವದವರು.
# 1        "ಆದರೆ ಸತ್ಯ ಹೊರ ಬಂದೇ ಬರುತ್ತದೆ ಎಂದು ಹೇಳಿದ ರಾಹುಲ್...
# 2                                 ಕಳ್ಳತನವಾಗಿದ್ದ 8 ಲಕ್ಷ ರೂ.
# 3                        ಇದರ ಬಗ್ಗೆ ನಾನೂ ಸಾಕಷ್ಟು ಓದಿದ್ದೇನೆ.
# 4        ಆಕೆಯ ತಲೆಯ ಹತ್ತಿರ ಇರಿಸಿಕೊಂಡಿದ್ದ ಫೋನ್‌ನ ಬ್ಯಾಟರಿ ...
# ...                                                    ...
# 1023376  ಈ ಸಂಬಂಧ ದೇವನಹಳ್ಳಿ ಪೆÇಲೀಸರು ಪ್ರಕರಣ ದಾಖಲಿಸಿಕೊಂಡಿ...
# 1023377  ರೋಗಿಗಳಿಗೆ ಚಿಕಿತ್ಸೆ ಕೊಡೋದಕ್ಕೆ ಅಲ್ಲಿ ಸರಿಯಾದ ವ್ಯವ...
# 1023378                                  ಖಾತೆ ನಂಬರ್ + IFSC
# 1023379         ಸುದ್ದಿ ಊರಿನಲ್ಲೆಲ್ಲಾ ಕಾಡ್ಗಿಚ್ಚಿನಂತೆ ಹರಡಿತು.
# 1023380  ( ಯೆರೆಮಿಾಯ 32: 9, 10) ಸಾಲವನ್ನು ಸ್ವತಃ ನೀವೇ ಹೋಗಿ...
#
# [1023381 rows x 2 columns]

# %% [markdown]
# Save the processed data to csv files for further processing.
# ```

# %%
en_kn_df.to_csv(save_dir / 'en_kannada.csv', index=False)
